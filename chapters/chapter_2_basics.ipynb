# %% [markdown]
# # 第2章: PHPの基礎を学ぼう
#
# ## 学習目標
# - PHPの基本的な文法を理解する
# - 変数、データ型、演算子を使えるようになる
# - 条件分岐の基本をマスターする
#
# ## 🎯 今回の学習内容
# - 変数と定数の使い方
# - 演算子の種類と使い方
# - 文字列操作の基本
# - 配列の基本操作

# %% [markdown]
# ---
#
# > 💡 **ヒント**: PHPでは変数名は `$` から始めます！

# %% [markdown]
# ## 1. 変数と定数
#
# ### 変数の使い方

# %%
<language>php</language><?php
// 変数は $ をつける
$name = "佐藤花子";
$age = 22;
$scores = [85, 92, 78];

// 変数の値を表示
echo "名前: " . $name . "\n";
echo "年齢: " . $age . "歳\n";
echo "1回目のテスト: " . $scores[0] . "点\n";
echo "2回目のテスト: " . $scores[1] . "点\n";
echo "3回目のテスト: " . $scores[2] . "点\n";
?>

# %% [markdown]
# **実行結果:**
# ```
# 名前: 佐藤花子
# 年齢: 22歳
# 1回目のテスト: 85点
# 2回目のテスト: 92点
# 3回目のテスト: 78点
# ```

# %% [markdown]
# ### 変数のルール
#
# - 変数名は `$` から始める
# - アルファベット、数字、アンダースコアが使える
# - 数字で始められない
# - 大文字と小文字は区別される

# %%
<language>php</language><?php
// OKな変数名
$user_name = "yamada";
$user1 = "taro";
$_private = "secret";

// NGな変数名
// 1user = "invalid";  // 数字で始まる
// user-name = "invalid";  // ハイフンは使えない
?>

# %% [markdown]
# ### 定数

# %%
<language>php</language><?php
// define() で定数を定義
define("TAX_RATE", 0.1);
define("SITE_NAME", "学習サイト");
define("VERSION", "1.0");

// 定数は $ をつけずに使う
echo "サイト名: " . SITE_NAME . "\n";
echo "税率: " . (TAX_RATE * 100) . "%\n";
echo "バージョン: " . VERSION . "\n";
?>

# %% [markdown]
# **実行結果:**
# ```
# サイト名: 学習サイト
# 税率: 10%
# バージョン: 1.0
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 2. データ型

# %% [markdown]
# | 型 | 説明 | 例 |
# |----|------|-----|
# | String | 文字列 | `"こんにちは"` |
# | Integer | 整数 | `123` |
# | Float | 浮動小数点 | `3.14` |
# | Boolean | 真偽値 | `true`, `false` |
# | Array | 配列 | `[1, 2, 3]` |
# | Null | 値なし | `null` |

# %%
<language>php</language><?php
$name = "田中";
$age = 30;
$is_admin = true;
$price = 99.99;
$scores = [85, 90, 78];

// 型を確認
var_dump($name);
var_dump($age);
var_dump($is_admin);
var_dump($price);
var_dump($scores);
?>

# %% [markdown]
# **実行結果:**
# ```
# string(6) "田中"
# int(30)
# bool(true)
# float(99.99)
# array(3) {
#   [0]=>
#   int(85)
#   [1]=>
#   int(90)
#   [2]=>
#   int(78)
# }
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 演算子

# %% [markdown]
# ### 算術演算子

# %%
<language>php</language><?php
$a = 10;
$b = 3;

echo "a = $a, b = $b\n";
echo "加算: " . ($a + $b) . "\n";
echo "減算: " . ($a - $b) . "\n";
echo "乗算: " . ($a * $b) . "\n";
echo "除算: " . ($a / $b) . "\n";
echo "剰余: " . ($a % $b) . "\n";
echo "冪乗: " . ($a ** $b) . "\n";
?>

# %% [markdown]
# **実行結果:**
# ```
# a = 10, b = 3
# 加算: 13
# 減算: 7
# 乗算: 30
# 除算: 3.3333333333333
# 剰余: 1
# 冪乗: 1000
# ```

# %% [markdown]
# ### 比較演算子

# %%
<language>php</language><?php
$a = 5;
$b = "5";

// 等価（値が等しい）
if ($a == $b) {
    echo "aとbは等しい（値）\n";
}

// 同一（値と型が両方等しい）
if ($a === $b) {
    echo "aとbは等しい（値と型）\n";
} else {
    echo "値は等しいが型が違う\n";
}

// 比較
if ($a > 3) {
    echo "aは3より大きい\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# aとbは等しい（値）
# 値は等しいが型が違う
# aは3より大きい
# ```

# %% [markdown]
# ### 論理演算子

# %%
<language>php</language><?php
$age = 20;
$is_student = true;
$has_discount = false;

// かつ（AND）
if ($age >= 18 && $is_student) {
    echo "成人の学生です\n";
}

// または（OR）
if ($age < 18 || $is_student) {
    echo "未成年または学生です\n";
}

// でない（NOT）
if (!$has_discount) {
    echo "割引はありません\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# 成人の学生です
# 未成年または学生です
# 割引はありません
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 4. 文字列操作

# %% [markdown]
# ### 文字列の連結

# %%
<language>php</language><?php
$name = "鈴木";
$greeting = "こんにちは、" . $name . "さん！";
echo $greeting . "\n";

// 複数行の文字列
$multi_line = <<<EOT
これは複数行の
文字列です。
EOT;

echo $multi_line;
?>

# %% [markdown]
# **実行結果:**
# ```
# こんにちは、鈴木さん！
# これは複数行の
# 文字列です。
# ```

# %% [markdown]
# ### 文字列関数

# %%
<language>php</language><?php
$text = "PHP学習";

// 文字列の長さ
echo "文字列の長さ: " . strlen($text) . "\n";

// 部分文字列
echo "部分文字列: " . substr($text, 0, 2) . "\n";

// 文字列の置換
echo "置換後: " . str_replace("PHP", "JavaScript", $text) . "\n";

// 小文字・大文字変換
echo "小文字: " . strtolower("HELLO") . "\n";
echo "大文字: " . strtoupper("hello") . "\n";
?>

# %% [markdown]
# **実行結果:**
# ```
# 文字列の長さ: 4
# 部分文字列: PH
# 置換後: JavaScript学習
# 小文字: hello
# 大文字: HELLO
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 5. 配列の基本

# %%
<language>php</language><?php
// 連想配列
$user = [
    "name" => "山田太郎",
    "age" => 25,
    "city" => "東京"
];

// 値の取得
echo "名前: " . $user["name"] . "\n";
echo "年齢: " . $user["age"] . "歳\n";
echo "住まい: " . $user["city"] . "\n";

// 値の変更
$user["age"] = 26;
echo "更新後の年齢: " . $user["age"] . "歳\n";
?>

# %% [markdown]
# **実行結果:**
# ```
# 名前: 山田太郎
# 年齢: 25歳
# 住まい: 東京
# 更新後の年齢: 26歳
# ```

# %% [markdown]
# ### 配列のループ

# %%
<language>php</language><?php
// 配列のループ
$fruits = ["りんご", "ばなな", "みかん"];

echo "果物の一覧:\n";
foreach ($fruits as $fruit) {
    echo "- " . $fruit . "\n";
}

// 連想配列のループ
$user = [
    "name" => "佐藤",
    "age" => 30,
    "city" => "大阪"
];

echo "\nユーザー情報:\n";
foreach ($user as $key => $value) {
    echo "- $key: $value\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# 果物の一覧:
# - りんご
# - ばなな
# - みかん
#
# ユーザー情報:
# - name: 佐藤
# - age: 30
# - city: 大阪
# ```

# %% [markdown]
# ### 問題1: 四則演算
#
# 以下の変数を使って計算結果を表示してください。
#
# <language>php</language><?php
# $x = 15;
# $y = 4;
#
# // ここにコードを書いてみよう
# echo "x + y = " . ($x + $y) . "\n";
# echo "x - y = " . ($x - $y) . "\n";
# echo "x * y = " . ($x * $y) . "\n";
# echo "x / y = " . ($x / $y) . "\n";
# echo "x % y = " . ($x % $y) . "\n";
# ?>
#
# ### 問題2: 文字列の連結
#
# 以下の変数を使って挨拶文を作成してください。
#
# <language>php</language><?php
# $greeting = "こんにちは";
# $name = "山田さん";
# $time = "おはようございます";
#
# // ここにコードを書いてみよう
# echo $time . ", " . $name . "！\n";
# ?>

# %% [markdown]
# ---
#
# ## まとめ
#
# ### ✅ ポイントチェック
#
# - [ ] 変数は `$` から始まる
# - [ ] 定数は `define()` で定義
# - [ ] 主なデータ型を理解した
# - [ ] 演算子の使い方がわかった
# - [ ] 配列の基本がわかった
#
# ### 🚀 次のステップ
#
# 次は「条件分岐」で、プログラムの流れを制御する方法を学びましょう！
#
# ### 💡 復習のポイント
# - PHPコードは `<?php ?>` で囲む
# - 文の最後はセミコロン（;）で終える
# - 変数を使うことで動的なプログラムが書ける
# - 配列で複数のデータをまとめて管理できる
