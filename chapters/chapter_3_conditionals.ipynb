# %% [markdown]
# # 第3章: 条件分岐
#
# ## 学習目標
# - if文の基本的な使い方を理解する
# - 条件によって処理を分岐させる方法をマスターする
# - 複雑な条件式を書けるようになる
#
# ## 🎯 今回の学習内容
# - if-else構文の使い方
# - 複数条件の組み合わせ
# - switch文の使い方
# - 三項演算子

# %% [markdown]
# ---
#
# > 💡 **ヒント**: 条件分岐でプログラムの流れを制御しましょう！

# %% [markdown]
# ## 1. if文の基本

# %% [markdown]
# ### 単純なif文

# %%
<language>php</language><?php
$age = 20;

if ($age >= 18) {
    echo "成年です\n";
} else {
    echo "未成年です\n";
}
?>

# %% [markdown]
# **実行結果（age = 20の場合）:**
# ```
# 成年です
# ```
#
# **実行結果（age = 16の場合）:**
# ```
# 未成年です
# ```

# %% [markdown]
# ### if-elseif-else構文

# %%
<language>php</language><?php
$score = 85;

if ($score >= 90) {
    echo "優秀\n";
} elseif ($score >= 80) {
    echo "良い\n";
} elseif ($score >= 70) {
    echo "合格\n";
} else {
    echo "不合格\n";
}
?>

# %% [markdown]
# **実行結果（score = 85の場合）:**
# ```
# 良い
# ```
#
# **他のスコアの場合:**
# - 95 → 優秀
# - 75 → 合格
# - 60 → 不合格

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 複数条件の組み合わせ

# %% [markdown]
# ### AND条件（&&）

# %%
<language>php</language><?php
$age = 25;
$is_student = true;

if ($age >= 18 && $is_student) {
    echo "成人の学生です\n";
} else {
    echo "条件に該当しません\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# 成人の学生です
# ```

# %% [markdown]
# ### OR条件（||）

# %%
<language>php</language><?php
$age = 16;
$has_parent = true;

if ($age < 18 || $has_parent) {
    echo "保護者同伴が必要です\n";
} else {
    echo "一人で入場可能です\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# 保護者同伴が必要です
# ```

# %% [markdown]
# ### NOT条件（!）

# %%
<language>php</language><?php
$is_admin = false;

if (!$is_admin) {
    echo "管理者ではありません\n";
} else {
    echo "管理者です\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# 管理者ではありません
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 比較演算子

# %%
<language>php</language><?php
$a = 5;
$b = "5";

// 等価（値が等しい）
if ($a == $b) {
    echo "aとbは等しい（値）\n";
}

// 同一（値と型が両方等しい）
if ($a === $b) {
    echo "aとbは等しい（値と型）\n";
} else {
    echo "値は等しいが型が違う\n";
}

// 比較
if ($a > 3) {
    echo "aは3より大きい\n";
}
?>

# %% [markdown]
# **実行結果:**
# ```
# aとbは等しい（値）
# 値は等しいが型が違う
# aは3より大きい
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 4. switch文

# %% [markdown]
# ### switch文の基本

# %%
<language>php</language><?php
$day = "月曜日";

switch ($day) {
    case "月曜日":
        echo "仕事の始まりです！頑張りましょう\n";
        break;
    case "火曜日":
        echo "週半ばです！もうすぐ金曜日\n";
        break;
    case "水曜日":
        echo "ハンプデー！少し疲れました\n";
        break;
    case "木曜日":
        echo "明日は金曜日！がんばれ\n";
        break;
    case "土曜日":
    case "日曜日":
        echo "週末！リラックスしましょう\n";
        break;
    default:
        echo "平日です\n";
}
?>

# %% [markdown]
# **実行結果（day = "月曜日"の場合）:**
# ```
# 仕事の始まりです！頑張りましょう
# ```

# %% [markdown]
# ### 複数条件をまとめる

# %%
<language>php</language><?php
$score = 85;

switch (true) {
    case $score >= 90:
        echo "A評価\n";
        break;
    case $score >= 80:
        echo "B評価\n";
        break;
    case $score >= 70:
        echo "C評価\n";
        break;
    default:
        echo "D評価\n";
}
?>

# %% [markdown]
# **実行結果（score = 85の場合）:**
# ```
# B評価
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 5. 三項演算子

# %% [markdown]
# ### 基本的な三項演算子

# %%
<language>php</language><?php
$age = 20;
$message = ($age >= 18) ? "成年です" : "未成年です";
echo $message . "\n";

// ネストした三項演算子
$score = 85;
$result = ($score >= 80) ?
    ($score >= 90 ? "優秀" : "良い") :
    "頑張りましょう";
echo $result . "\n";
?>

# %% [markdown]
# **実行結果:**
# ```
# 成年です
# 良い
# ```

# %% [markdown]
# ### 問題1: BMI計算器
#
# BMIを計算して健康状態を表示するプログラムを作成してください。
#
# <language>php</language><?php
# $weight = 65;  // kg
# $height = 1.70; // m
#
# // BMI = 体重(kg) / (身長(m) * 身長(m))
# // BMI < 18.5: 痩せ型
# // 18.5 <= BMI < 25: 普通体重
# // BMI >= 25: 肥満
#
# // ここにコードを書いてみよう
# $bmi = $weight / ($height * $height);
#
# if ($bmi < 18.5) {
#     echo "BMI: " . round($bmi, 1) . " - 痩せ型\n";
# } elseif ($bmi < 25) {
#     echo "BMI: " . round($bmi, 1) . " - 普通体重\n";
# } else {
#     echo "BMI: " . round($bmi, 1) . " - 肥満\n";
# }
# ?>
#
# ### 問題2: 会員ランク判定
#
# 購入額に応じて会員ランクを判定してください。
#
# <language>php</language><?php
# $purchase_amount = 50000; // 購入額
#
# // 0-9999: 一般会員
# // 10000-49999: シルバー会員
# // 50000-99999: ゴールド会員
# // 100000-: プラチナ会員
#
# // ここにコードを書いてみよう
# if ($purchase_amount < 10000) {
#     echo "一般会員\n";
# } elseif ($purchase_amount < 50000) {
#     echo "シルバー会員\n";
# } elseif ($purchase_amount < 100000) {
#     echo "ゴールド会員\n";
# } else {
#     echo "プラチナ会員\n";
# }
# ?>

# %% [markdown]
# ---
#
# ## まとめ
#
# ### ✅ ポイントチェック
#
# - [ ] if文の基本構文が理解できた
# - [ ] 複数条件の組み合わせ方がわかった
# - [ ] 比較演算子の使い方がわかった
# - [ ] switch文の使い方がわかった
# - [ ] 三項演算子が使えるようになった
#
# ### 🚀 次のステップ
#
# 次は「配列を使ってみよう」で、データをまとめて扱う方法を学びましょう！
#
# ### 💡 復習のポイント
# - if文で条件に応じて処理を分岐
# - && でAND条件、|| でOR条件
# - switch文で多岐にわたる条件を整理
