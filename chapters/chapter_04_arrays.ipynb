# %% [markdown]
# # 配列を使ってみよう
#
# ## 学習目標
# - 配列の基本的な使い方を理解する
# - 配列の操作方法をマスターする
# - 配列を使った実用的なプログラムが書けるようになる
#
# ---

# %% [markdown]
# ## 1. 配列の基本
#
# ### 配列とは？
#
# 配列は**複数のデータをまとめて管理**できるデータ構造です。

# %%
<?php
// シンプルな配列の作成
$colors = ["赤", "青", "緑"];

// 配列の要素にアクセス
echo $colors[0]; // 赤 (0番目)
echo $colors[1]; // 青 (1番目)
echo $colors[2]; // 緑 (2番目)
?>

# %% [markdown]
# ### 配列の作り方

# %%
<?php
// 方法1: [] で作成
$fruits = ["りんご", "ばなな", "みかん"];

// 方法2: array() で作成
$colors = array("赤", "青", "黄");

// 空の配列
$empty_array = [];
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 連想配列
#
# ### 連想配列とは？
#
# キーと値のペアでデータを管理する配列です。

# %%
<?php
// 連想配列の作成
$user = [
    "name" => "田中太郎",
    "age" => 25,
    "city" => "東京"
];

// キーを使ってアクセス
echo $user["name"]; // 田中太郎
echo $user["age"];  // 25
echo $user["city"]; // 東京
?>

# %% [markdown]
# ### 連想配列のネスト

# %%
<?php
// ネストした連想配列
$company = [
    "name" => "テック株式会社",
    "departments" => [
        "開発部" => ["田中", "佐藤"],
        "営業部" => ["鈴木", "山田"]
    ],
    "founded" => 2020
];

// ネストした配列へのアクセス
echo $company["departments"]["開発部"][0]; // 田中
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 配列の操作
#
# ### 要素の追加

# %%
<?php
$fruits = ["りんご", "ばなな"];

// 配列の末尾に追加
$fruits[] = "みかん";

// 特定の位置に挿入
array_splice($fruits, 1, 0, "ぶどう");

// 連想配列に追加
$user = ["name" => "田中"];
$user["email"] = "tanaka@example.com";
?>

# %% [markdown]
# ### 要素の削除

# %%
<?php
$colors = ["赤", "青", "緑", "黄"];

// 最後の要素を削除
array_pop($colors); // "黄" が削除される

// 最初の要素を削除
array_shift($colors); // "赤" が削除される

// 特定の要素を削除
unset($colors[1]); // インデックス1を削除
?>

# %% [markdown]
# ### 要素の変更

# %%
<?php
$scores = [80, 90, 70, 85];

// 要素を直接変更
$scores[2] = 75;

// 範囲を変更
array_splice($scores, 1, 2, [95, 88]);
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 4. 配列の関数
#
# ### 配列の長さ

# %%
<?php
$colors = ["赤", "青", "緑"];

// 要素数を取得
$count = count($colors); // 3
echo "配列の要素数: $count\n";
?>

# %% [markdown]
# ### 配列の結合

# %%
<?php
$fruits1 = ["りんご", "ばなな"];
$fruits2 = ["みかん", "ぶどう"];

// 配列を結合
$all_fruits = array_merge($fruits1, $fruits2);
print_r($all_fruits);
?>

# %% [markdown]
# ### 配列のソート

# %%
<?php
$numbers = [3, 1, 4, 2, 5];

// 昇順ソート
sort($numbers);
print_r($numbers);

// 降順ソート
rsort($numbers);
print_r($numbers);

// 連想配列のソート
$users = [
    ["name" => "田中", "age" => 25],
    ["name" => "佐藤", "age" => 30],
    ["name" => "鈴木", "age" => 22]
];

// 年齢でソート
usort($users, function($a, $b) {
    return $a["age"] - $b["age"];
});
print_r($users);
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 5. 配列のループ
#
# ### foreachでループ

# %%
<?php
// 通常の配列のループ
$colors = ["赤", "青", "緑"];
foreach ($colors as $color) {
    echo "色: $color\n";
}

// 連想配列のループ
$user = ["name" => "田中", "age" => 25];
foreach ($user as $key => $value) {
    echo "$key: $value\n";
}

// キーのみを取得
foreach ($user as $key => $value) {
    echo "キー: $key\n";
}

// 値のみを取得
foreach ($user as $value) {
    echo "値: $value\n";
}
?>

# %% [markdown]
# ### for文でループ

# %%
<?php
$colors = ["赤", "青", "緑", "黄"];

// インデックスを使ったループ
for ($i = 0; $i < count($colors); $i++) {
    echo "$i: {$colors[$i]}\n";
}
?>

# %% [markdown]
# ### while文でループ

# %%
<?php
$colors = ["赤", "青", "緑", "黄"];
$index = 0;

while ($index < count($colors)) {
    echo "$index: {$colors[$index]}\n";
    $index++;
}
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 6. 多次元配列
#
# ### 2次元配列

# %%
<?php
// 成績表の2次元配列
$scores = [
    ["国語", 85],
    ["数学", 92],
    ["英語", 78],
    ["理科", 88]
];

// ループで表示
foreach ($scores as $score) {
    echo $score[0] . ": " . $score[1] . "点\n";
}

// 特定の要素にアクセス
echo $scores[1][0]; // 数学
echo $scores[1][1]; // 92
?>

# %% [markdown]
# ### 3次元以上の配列

# %%
<?php
// 3次元配列の例
$school = [
    "classA" => [
        "1組" => ["田中", "佐藤"],
        "2組" => ["鈴木", "山田"]
    ],
    "classB" => [
        "1組" => ["イチロー", "ジロウ"],
        "2組" => "サトウ"
    ]
];

// 3次元配列へのアクセス
echo $school["classA"]["1組"][0]; // 田中
echo $school["classB"]["1組"][1]; // ジロウ
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 7. 配列の検索
#
# ### 値の検索

# %%
<?php
$fruits = ["りんご", "ばなな", "みかん", "ぶどう"];

// 値が存在するか確認
if (in_array("みかん", $fruits)) {
    echo "みかんがあります\n";
}

// 値の位置を取得
$pos = array_search("ばなな", $fruits);
echo "ばななは $pos 番目です\n";
?>

# %% [markdown]
# ### キーの検索

# %%
<?php
$user = [
    "name" => "田中",
    "age" => 25,
    "email" => "tanaka@example.com"
];

// キーが存在するか確認
if (array_key_exists("email", $user)) {
    echo "メールアドレスがあります\n";
}
?>

# %% [markdown]
# ### 複数条件で検索

# %%
<?php
$users = [
    ["name" => "田中", "age" => 25, "city" => "東京"],
    ["name" => "佐藤", "age" => 30, "city" => "大阪"],
    ["name" => "鈴木", "age" => 25, "city" => "東京"]
];

// 条件に一致するユーザーを検索
$results = array_filter($users, function($user) {
    return $user["age"] == 25 && $user["city"] == "東京";
});

print_r($results);
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 8. 配列の変換
#
# ### 文字列と配列の変換

# %%
<?php
// 文字列を配列に分割
$text = "赤,青,緑,黄";
$colors = explode(",", $text);
print_r($colors);

// 配列を文字列に結合
$fruits = ["りんご", "ばなな", "みかん"];
$fruits_text = implode(",", $fruits);
echo $fruits_text; // りんご,ばなな,みかん
?>

# %% [markdown]
# ### 配列を結合・分割

# %%
<?php
$a = [1, 2, 3];
$b = [4, 5, 6];

// 配列を結合
$c = array_combine($a, $b);
print_r($c);

// 配列を分割
$chunked = array_chunk($a, 2);
print_r($chunked);
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 9. 練習問題
#
# ### 問題1: 商品リストの作成

# %%
<?php
// 商品名と価格の連想配列を作成
// 商品一覧を表示
// 合計金額を計算
?>

# %% [markdown]
# ### 問題2: グレード判定システム

# %%
<?php
// 学生の名前とテストの点数を配列で管理
// 80点以上: A
// 70-79点: B
// 60-69点: C
// 60点未満: D
?>

# %% [markdown]
# ### 問題3: 在庫管理

# %%
<?php
// 商品名と在庫数の連想配列
// 商品の在庫チェック
// 在庫が少ないものを警告表示
?>

# %% [markdown]
# ---

# %% [markdown]
# ## 10. ベストプラクティス
#
# ### 配列の使い方のポイント

# %% [markdown]
# 1. **意味のあるキーを使う**

# %%
<?php
// より読みやすい
$user["name"] = "田中";
$user["email"] = "tanaka@example.com";

// 読みにくい
$user[0] = "田中";
$user[1] = "tanaka@example.com";
?>

# %% [markdown]
# 2. **データの整合性を保つ**

# %%
<?php
// 似たようなデータは同じ構造に
$users = [
    ["name" => "田中", "age" => 25],
    ["name" => "佐藤", "age" => 30]
];

// 構造が揃っていないと扱いにくい
$data = [
    "name" => "田中",
    ["age" => 25]
];
?>

# %% [markdown]
# 3. **適切な関数を選ぶ**
#    - `count()` - 要素数
#    - `in_array()` - 値の存在チェック
#    - `array_filter()` - 条件で絞り込み
#    - `array_map()` - 全要素に処理

# %% [markdown]
# ---

# %% [markdown]
# ## 11. まとめ
#
# ### 📝 ポイントチェック
#
# - [ ] 配列の基本的な使い方がわかった
# - [ ] 連想配列の使い方がわかった
# - [ ] 配列の操作方法がわかった
# - [ ] 配列のループが書けるようになった
# - [ ] 多次元配列が扱えるようになった
#
# ### 🚀 次のステップ
#
# 次は「繰り返し処理」で、同じ処理を繰り返し実行する方法を学びましょう！
#
# ---

# %% [markdown]
# **関連リソース**
# - [PHP配列の公式ドキュメント](https://www.php.net/manual/ja/language.types.array.php)
# - [PHP配列関数リファレンス](https://www.php.net/manual/ja/ref.array.php)
