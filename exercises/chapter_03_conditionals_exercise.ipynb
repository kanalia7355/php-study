# %% [markdown]
# # 第3章: 条件分岐 - 課題集
#
# ## 学習目標
# - if文を使って条件によって処理を分けられる
# - switch文で多方向分岐ができる
# - 三項演算子を使った簡潔な条件式が書ける
# - 複雑な条件を組み合わせて判定できる
#
# ---
#
# ## 課題1: 基本的なif文
#
# ### 目標
# if文の基本構造を理解し、簡単な条件分岐ができるようになりましょう。
#
# ### 問題
# 入力された数値が正の数、負の数、ゼロのどれかを判定するプログラムを作成してください。
#
# **変数:**
# ```php
# $number = -5;
# ```
#
# **期待する出力:**
# - 正の数の場合: 「正の数です」
# - 負の数の場合: 「負の数です」
# - ゼロの場合: 「ゼロです」

# %%
<language>php</language><?php
$number = -5;

// ここに条件分岐のコードを書いてください


?>

# %% [markdown]
# ### 確認ポイント
# - if-elseif-else構造を使いましたか？
# - 異なる値（正、負、ゼロ）でテストしましたか？
# - 適切な比較演算子を使いましたか？

# %% [markdown]
# ---
#
# ## 課題2: 年齢による区分判定
#
# ### 目標
# 複数の条件を使って、年齢に応じた区分を判定できるようになりましょう。
#
# ### 問題
# 年齢に基づいて以下の区分を判定するプログラムを作成してください。
#
# **区分ルール:**
# - 0〜12歳: 「子供」
# - 13〜19歳: 「若者（ティーンエイジャー）」
# - 20〜64歳: 「成人」
# - 65歳以上: 「シニア」
#
# **変数:**
# ```php
# $age = 17;
# ```

# %%
<language>php</language><?php
$age = 17;

// ここに条件分岐のコードを書いてください


?>

# %% [markdown]
# ### 確認ポイント
# - 境界値（12、13、19、20、64、65）で正しく動作しますか？
# - 全ての年齢範囲をカバーしていますか？
# - 不正な値（負の数など）の場合はどうなりますか？

# %% [markdown]
# ---
#
# ## 課題3: switch文で曜日を判定
#
# ### 目標
# switch文を使って、値に応じた処理を分岐できるようになりましょう。
#
# ### 問題
# 曜日番号（0-6）に対応する曜日名とメッセージを表示するプログラムを作成してください。
#
# **曜日対応表:**
# - 0: 日曜日 - 「今日は日曜日です。ゆっくり休みましょう！」
# - 1: 月曜日 - 「今週も頑張りましょう！」
# - 2: 火曜日 - "火曜日です。調子はどうですか？"
# - 3: 水曜日 - "週の真ん中です！"
# - 4: 木曜日 - "もうすぐ週末です！"
# - 5: 金曜日 - "週末が近いです！"
# - 6: 土曜日 - "週末です。楽しみましょう！"
#
# **変数:**
# ```php
# $day = 3;
# ```

# %%
<language>php</language><?php
$day = 3;

// ここにswitch文を書いてください


?>

# %% [markdown]
# ### 確認ポイント
# - 各caseにbreakを入れましたか？（breakを忘れるとどうなりますか？）
# - defaultケースを用意しましたか？（無効な値の場合）
# - 0から6までの全ての値をテストしましたか？

# %% [markdown]
# ---
#
# ## 課題4: 三項演算子を使った条件式
#
# ### 目標
# 三項演算子を使って、簡潔な条件式が書けるようになりましょう。
#
# ### 問題
# 以下の条件を三項演算子を使って実装してください。
#
# **1. パスワードの強度判定**
# - 8文字以上: 「強い」
# - 8文字未満: 「弱い」
#
# **2. 奇数・偶数判定**
# - 奇数: 「奇数です」
# - 偶数: 「偶数です」
#
# **3. 会員価格の計算**
# - 会員: 10%引き
# - 非会員: 定価

# %%
<language>php</language><?php
// 1. パスワードの強度判定
$password = "mypassword";
$strength = ;  // ここに三項演算子を書いてください
echo "パスワード強度: " . $strength . "\n";

// 2. 奇数・偶数判定
$number = 7;
$result = ;  // ここに三項演算子を書いてください
echo "{$number}は" . $result . "\n";

// 3. 会員価格の計算
$price = 1000;
$is_member = true;
$member_price = ;  // ここに三項演算子を書いてください
echo "会員価格: " . $member_price . "円\n";
?>

# %% [markdown]
# ### 確認ポイント
# - 三項演算子の構文 `条件 ? 真の場合 : 偽の場合` を使いましたか？
# - 各条件で正しい結果が得られますか？
# - if文で書く場合と比べて、コードが簡潔になりましたか？

# %% [markdown]
# ---
#
# ## 課題5: 複合条件を使ったログイン認証
#
# ### 目標
# 複数の条件を組み合わせて、複雑な判定ができるようになりましょう。
#
# ### 問題
# ユーザーログインの認証システムを作成してください。
#
# **認証条件:**
# 1. ユーザー名とパスワードが正しいこと
# 2. アカウントが有効であること（`is_active`）
# 3. アカウントがロックされていないこと（`!is_locked`）
#
# **判定ロジック:**
# - 全条件満たす: 「ログイン成功」
# - パスワードが間違っている: 「パスワードが間違っています」
# - アカウントが無効: 「アカウントが無効です」
# - アカウントがロックされている: 「アカウントはロックされています」
# - ユーザーが存在しない: 「ユーザー名が間違っています」
#
# **入力データ:**
# ```php
# $input_username = "yamada";
# $input_password = "pass123";
# $valid_username = "yamada";
# $valid_password = "pass123";
# $is_active = true;
# $is_locked = false;
# ```

# %%
<language>php</language><?php
$input_username = "yamada";
$input_password = "pass123";
$valid_username = "yamada";
$valid_password = "pass123";
$is_active = true;
$is_locked = false;

// ここに認証ロジックを書いてください



?>

# %% [markdown]
# ### 確認ポイント
# - `&&`（AND）と `||`（OR）を適切に使い分けましたか？
# - 各エラーパターンを正しく判定できていますか？
# - エラーメッセージはユーザーフレンドリーですか？

# %% [markdown]
# ---
#
# ## 課題6: ネストした条件分岐 - 成績評価システム
#
# ### 目標
# 条件分岐をネストして、複雑なロジックを実装できるようになりましょう。
#
# ### 問題
# 学生の成績を評価するシステムを作成してください。
#
# **評価ルール:**
#
# 1. **試験の点数に基づく評価**
#    - 90点以上: A
#    - 80〜89点: B
#    - 70〜79点: C
#    - 60〜69点: D
#    - 60点未満: F
#
# 2. **特別措置**
#    - 出席率が90%以上: 成績を1つ上げる（AはAのまま）
#    - 出席率が60%未満: 成績を1つ下げる（FはFのまま）
#    - 課題を全て提出: ボーナスポイントとして"+"を付加
#
# **入力データ:**
# ```php
# $exam_score = 85;
# $attendance_rate = 92;
# $all_assignments_submitted = true;
# ```

# %%
<language>php</language><?php
$exam_score = 85;
$attendance_rate = 92;
$all_assignments_submitted = true;

// 成績を評価



// 出席率による調整


// 課題提出によるボーナス


// 結果を表示
echo "試験点数: " . $exam_score . "点\n";
echo "出席率: " . $attendance_rate . "%\n";
echo "課題提出: " . ($all_assignments_submitted ? "完了" : "未完了") . "\n";
echo "成績: " . $final_grade . "\n";
?>

# %% [markdown]
# ### 確認ポイント
# - ネストの深さは適切ですか？（深すぎませんか？）
# - 出席率による調整ロジックは正しいですか？
# - 全ての条件パターンをテストしましたか？
# - コードは読みやすいですか？

# %% [markdown]
# ---
#
# ## 課題7: 総合演習 - 料金計算システム
#
# ### 目標
# 実用的な料金計算システムを、条件分岐を使って実装しましょう。
#
# ### 問題
# タクシー会社の料金計算システムを作成してください。
#
# **料金ルール:**
#
# 1. **基本料金**
#    - 初乗り運賃: 500円（最初の1.5km）
#    - その後: 300円/1km（1km単位で加算、切り上げ）
#
# 2. **割引サービス**
#    - 深夜割引（23時〜5時）: 20%引き
#    - 会員割引: 10%引き
#    - 高齢者割引（65歳以上）: 15%引き
#    - ※ 割引は重複適用せず、最も高い率を適用
#
# 3. **追加料金**
#    - 空港増額: 1000円
#    - 大型荷物: 500円
#
# **入力データ:**
# ```php
# $distance = 12.3;        // 走行距離（km）
# $hour = 2;                // 現在時刻（24時間表記）
# $is_member = true;        // 会員かどうか
# $age = 70;                // 乗客の年齢
# $is_airport = false;      // 空港へ行くかどうか
# $has_large_luggage = true; // 大型荷物があるかどうか
# ```

# %%
<language>php</language><?php
$distance = 12.3;
$hour = 2;
$is_member = true;
$age = 70;
$is_airport = false;
$has_large_luggage = true;

// 1. 基本料金を計算


// 2. 割引率を決定（最も高い率を適用）


// 3. 割引を適用


// 4. 追加料金を加算


// 5. 合計料金を表示
echo "=== タクシー料金明細 ===\n";
echo "走行距離: " . $distance . "km\n";
// 以下、必要な項目を追加してください



?>

# %% [markdown]
# ### 確認ポイント
# - 走行距離の計算は正しいですか？（1.5km以降の計算）
# - 割引率の選択ロジックは正しいですか？（最も高い率）
# - 追加料金の計算は正しいですか？
# - 明細は見やすく表示されていますか？

# %% [markdown]
# ---
#
# ## 📊 学習チェックリスト
#
# この章の課題を終えたら、以下のチェックリストで理解度を確認しましょう。
#
# - [ ] if-else文の基本が書ける
# - [ ] elseifを使って多方向分岐ができる
# - [ ] switch文を使って値による分岐ができる
# - [ ] 三項演算子を使って簡潔な条件式が書ける
# - [ ] 複合条件（&&, ||）を使いこなせる
# - [ ] ネストした条件分岐が書ける
# - [ ] 実用的な条件判定システムが作れる
#
# ### 💡 次のステップ
#
# すべての課題が完了したら、次の章「配列」に進みましょう！
