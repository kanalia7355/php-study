# %% [markdown]
# # 第2章: PHPの基礎 - 課題集
#
# ## 学習目標
# - 演算子を使って計算ができる
# - 文字列操作ができる
# - 条件分岐の基本を理解する
# - 変数と定数の使い分けができる
#
# ---
#
# ## 課題1: 四則演算
#
# ### 目標
# 算術演算子を使って基本的な計算ができるようになりましょう。
#
# ### 問題
# 2つの変数 `$a = 15`, `$b = 4` を使って、以下の計算結果を表示してください。
#
# 1. 足し算（$a + $b）
# 2. 引き算（$a - $b）
# 3. 掛け算（$a * $b）
# 4. 割り算（$a / $b）
# 5. 剰余（$a % $b）- 余りを求める
# 6. 冪乗（$a ** $b）- 累乗
#
# **期待する出力形式:**
# ```
# 足し算: 15 + 4 = 19
# 引き算: 15 - 4 = 11
# ...
# ```

# %%
<language>php</language><?php
$a = 15;
$b = 4;

// ここに計算コードを書いてください


?>

# %% [markdown]
# ### 確認ポイント
# - すべての演算子を使いましたか？（+, -, *, /, %, **）
# - 剰余の結果は正しいですか？（15 ÷ 4 = 3 余り 1）
# - 冪乗の結果は正しいですか？（15の4乗）

# %% [markdown]
# ---
#
# ## 課題2: 比較演算子の理解
#
# ### 目標
# 値を比較して、その結果を判定できるようになりましょう。
#
# ### 問題
# 以下の比較を行い、結果を表示してください。
#
# **変数:**
# ```php
# $x = 10;
# $y = "10";
# $z = 5;
# ```
#
# **比較する項目:**
# 1. `$x == $y` （値が等しいか）
# 2. `$x === $y` （値と型が等しいか）
# 3. `$x > $z` （$xは$zより大きいか）
# 4. `$x != $z` （$xと$zは等しくないか）
#
# 結果は `var_dump()` で表示し、型も確認してください。

# %%
<language>php</language><?php
$x = 10;
$y = "10";
$z = 5;

// ここに比較コードを書いてください


?>

# %% [markdown]
# ### 確認ポイント
# - `==` と `===` の違いが結果に表れていますか？
# - 比較の結果はboolean型（true/false）ですか？
# - 各比較演算子の意味を理解できましたか？

# %% [markdown]
# ---
#
# ## 課題3: 論理演算子を使った条件判定
#
# ### 目標
# 複数の条件を組み合わせて判定できるようになりましょう。
#
# ### 問題
# 以下のシナリオで条件判定を行ってください。
#
# **シナリオ: 割引価格の計算**
#
# 会員ランクと年齢に応じて割引を適用するプログラムを作成してください。
#
# **変数:**
# ```php
# $is_premium_member = true;  // プレミアム会員かどうか
# $age = 65;                  // 年齢
# $price = 1000;              // 商品価格
# ```
#
# **割引ルール:**
# - プレミアム会員かつ65歳以上: 20%割引
# - プレミアム会員または65歳以上: 10%割引
# - それ以外: 割引なし
#
# 最終的な価格を計算して表示してください。

# %%
<language>php</language><?php
$is_premium_member = true;
$age = 65;
$price = 1000;

// 割引率を決定してください
$discount_rate = 0;  // ここに条件判定を追加

// 割引後の価格を計算
$final_price = $price * (1 - $discount_rate);

// 結果を表示
echo "元の価格: " . $price . "円\n";
echo "割引率: " . ($discount_rate * 100) . "%\n";
echo "最終価格: " . $final_price . "円\n";
?>

# %% [markdown]
# ### 確認ポイント
# - `&&`（AND）と `||`（OR）を正しく使い分けましたか？
# - 複数の条件を適切に組み合わせられましたか？
# - 割引率の計算は正しいですか？

# %% [markdown]
# ---
#
# ## 課題4: 文字列操作
#
# ### 目標
# 文字列関数を使ってテキストを加工できるようになりましょう。
#
# ### 問題
# 以下の文字列操作を行ってください。
#
# ```php
# $text = "  Hello PHP Programming  ";
# ```
#
# **実行する操作:**
# 1. 文字列の長さを取得（`strlen()`）
# 2. 前後の空白を削除（`trim()`）
# 3. 「PHP」を「World」に置換（`str_replace()`）
# 4. すべて大文字に変換（`strtoupper()`）
# 5. すべて小文字に変換（`strtolower()`）
# 6. 最初の5文字を取得（`substr()`）

# %%
<language>php</language><?php
$text = "  Hello PHP Programming  ";

// 文字列操作を実行してください


?>

# %% [markdown]
# ### 確認ポイント
# - 各関数の結果を確認しましたか？
# - `trim()` 後の文字列長が変わっていますか？
# - `substr()` で正しく文字を取得できましたか？（インデックスは0から）

# %% [markdown]
# ---
#
# ## 課題5: 定数と変数
#
# ### 目標
# 定数と変数の違いを理解して、適切に使い分けましょう。
#
# ### 問題
# ショッピングサイトの合計金額計算プログラムを作成してください。
#
# **定数（変更不可）:**
# - 消費税率: 10%
# - 送料: 500円
#
# **変数（変更可）:**
# - 商品価格
# - 商品数量
# - 会員割引フラグ
#
# **計算ロジック:**
# 1. 小計 = 商品価格 × 数量
# 2. 会員割引適用（会員なら5%引き）
# 3. 消費税を計算
# 4. 送料を追加（小計が5000円以上なら無料）
# 5. 合計金額を表示

# %%
<language>php</language><?php
// 定数を定義してください


// 変数を設定
$product_price = 2500;
$quantity = 3;
$is_member = true;

// 合計金額を計算してください



// 結果を表示
echo "=== 請求明細 ===\n";
echo "商品価格: " . $product_price . "円\n";
echo "数量: " . $quantity . "\n";
// 以下、必要な項目を追加してください


?>

# %% [markdown]
# ### 確認ポイント
# - `define()` で定数を定義しましたか？
# - 定数名は大文字にしましたか？（慣習）
# - 会員割引と送料無料の条件分岐は正しいですか？
# - 消費税の計算は正しいですか？（小計に対して計算）

# %% [markdown]
# ---
#
# ## 課題6: 総合演習 - 成績計算プログラム
#
# ### 目標
# 学んだ内容を組み合わせて、実用的なプログラムを作りましょう。
#
# ### 問題
# 学生の成績を計算して、評価を判定するプログラムを作成してください。
#
# **入力データ:**
# - 学生の名前
# - 国語、数学、英語の点数（各0〜100点）
# - 出席率（0〜100%）
#
# **計算と判定:**
# 1. 3教科の平均点を計算
# 2. 平均点に基づいて成績を判定
#    - 90点以上: S
#    - 80点以上: A
#    - 70点以上: B
#    - 60点以上: C
#    - 60点未満: D
# 3. 出席率が80%未満なら成績を1つ下げる
# 4. 最終結果を表示

# %%
<language>php</language><?php
// 入力データ
$name = "田中太郎";
$japanese_score = 85;
$math_score = 92;
$english_score = 78;
$attendance_rate = 75;

// 平均点を計算


// 成績を判定


// 出席率による調整


// 結果を表示
echo "=== 成績通知書 ===\n";
echo "学生名: " . $name . "\n";
echo "平均点: " . $average . "点\n";
echo "出席率: " . $attendance_rate . "%\n";
echo "成績: " . $final_grade . "\n";
echo "==================\n";
?>

# %% [markdown]
# ### 確認ポイント
# - 平均点の計算は正しいですか？（小数点以下も考慮）
# - 成績判定のロジックは正しいですか？（境界値に注意）
# - 出席率による調整は正しく動作していますか？
# - 出力は見やすく整形されていますか？

# %% [markdown]
# ---
#
# ## 📊 学習チェックリスト
#
# この章の課題を終えたら、以下のチェックリストで理解度を確認しましょう。
#
# - [ ] 算術演算子（+, -, *, /, %, **）を使える
# - [ ] 比較演算子（==, ===, !=, <, >）を使える
# - [ ] 論理演算子（&&, ||, !）を使える
# - [ ] 文字列関数（strlen, trim, str_replaceなど）を使える
# - [ ] 定数と変数を使い分けられる
# - [ ] 複雑な条件分岐が書ける
# - [ ] 実用的な計算プログラムが作れる
#
# ### 💡 次のステップ
#
# すべての課題が完了したら、次の章「条件分岐」に進みましょう！
