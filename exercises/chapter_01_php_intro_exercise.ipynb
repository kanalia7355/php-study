# %% [markdown]
# # 第1章: PHPとは？ - 課題集
#
# ## 学習目標
# - PHPの基本構文を書けるようになる
# - 変数の使い方を理解する
# - データ型を区別できるようになる
#
# ---
#
# ## 課題1: 最初のPHPプログラム
#
# ### 目標
# 基本的なPHPコードを書いて、画面に文字を表示してみましょう。
#
# ### 問題
# 以下の要件を満たすPHPプログラムを書いてください。
#
# 1. `<?php ?>` タグを使う
# 2. `echo` を使って「こんにちは、PHP世界！」と表示する
# 3. 文の最後にセミコロン（;）をつける

# %%
<language>php</language><?php
// ここにコードを書いてください

?>

# %% [markdown]
# ### 確認ポイント
# - PHPタグで正しく囲まれていますか？
# - セミコロンをつけましたか？
# - 実行すると「こんにちは、PHP世界！」と表示されますか？

# %% [markdown]
# ---
#
# ## 課題2: 変数を使った自己紹介
#
# ### 目標
# 変数を使ってデータを保存し、表示してみましょう。
#
# ### 問題
# 自分の情報を変数に代入して、自己紹介文を作成してください。
#
# **必要な変数:**
# - `$name`: 名前
# - `$age`: 年齢
# - `$hobby`: 趣味
#
# **出力例:**
# ```
# 私の名前は山田太郎です。
# 年齢は25歳です。
# 趣味は読書です。
# ```

# %%
<language>php</language><?php
// 変数を定義してください


// 自己紹介文を表示してください

?>

# %% [markdown]
# ### 確認ポイント
# - 変数名が `$` で始まっていますか？
# - 文字列を `"` で囲んでいますか？
#  `- `.` で文字列を連結していますか？`
# - 出力が指定のフォーマットと一致しますか？

# %% [markdown]
# ---
#
# ## 課題3: データ型の理解
#
# ### 目標
# 異なるデータ型の変数を作成し、それぞれの型を確認してみましょう。
#
# ### 問題
# 以下のデータ型の変数を作成してください。
#
# 1. **String（文字列）**: 好きな食べ物
# 2. **Integer（整数）**: 今日の日付（日）
# 3. **Float（浮動小数点）**: 身長（例: 170.5）
# 4. **Boolean（真偽値）**: PHPは楽しい（true）
#
# それぞれの変数を `var_dump()` で表示して、型を確認してください。

# %%
<language>php</language><?php
// 各データ型の変数を作成してください
$favorite_food = "";
$today = ;
$height = ;
$is_fun = ;

// var_dump()で型を確認してください

?>

# %% [markdown]
# ### 確認ポイント
# - 文字列は `"` で囲んでいますか？
# - 数値には `"` をつけていませんか？
# - 真偽値は `true` または `false` ですか？
# - `var_dump()` の出力で型が正しく表示されますか？

# %% [markdown]
# ---
#
# ## 課題4: コメントの書き方
#
# ### 目標
# コードにコメントを書いて、読みやすいプログラムを作りましょう。
#
# ### 問題
# 以下のコードに適切なコメントを追加してください。
#
# **コメントの種類:**
# - 一行コメント: `//`
# - 複数行コメント: `/* */`

# %%
<language>php</language><?php
// 変数の定義にコメントを書いてください
$user_name = "";
$login_count = 0;

/*
 ここに複数行コメントを書いてください
 このプログラムの説明を記述しましょう
*/

echo "ようこそ！";
?>

# %% [markdown]
# ### 確認ポイント
# - 一行コメント `//` を使いましたか？
# - 複数行コメント `/* */` を使いましたか？
# - コメントは実行結果に影響しませんか？

# %% [markdown]
# ---
#
# ## 課題5: 総合演習 - プロフィール作成
#
# ### 目標
# 学んだ内容を組み合わせて、自分のプロフィールを作成しましょう。
#
# ### 問題
# 以下の情報を含むプロフィールを作成してください。
#
# **必要な情報:**
# - 名前（文字列）
# - 年齢（整数）
# - 身長（浮動小数点）
# - 趣味のリスト（配列）
# - 学生かどうか（真偽値）
#
# **出力フォーマット:**
# ```
# === プロフィール ===
# 名前: [名前]
# 年齢: [年齢]歳
# 身長: [身長]cm
# 趣味: [趣味1], [趣味2], [趣味3]
# 学生: [はい/いいえ]
# ===================
# ```

# %%
<language>php</language><?php
// プロフィール情報を変数に代入





// プロフィールを表示
echo "=== プロフィール ===\n";
// ここにコードを追加してください


echo "===================";
?>

# %% [markdown]
# ### 確認ポイント
# - すべてのデータ型を使いましたか？
# - 配列の要素を正しく表示できていますか？
# - 真偽値に応じて「はい/いいえ」を表示できていますか？
# - 出力が整形されていますか？

# %% [markdown]
# ---
#
# ## 📊 学習チェックリスト
#
# この章の課題を終えたら、以下のチェックリストで理解度を確認しましょう。
#
# - [ ] PHPの基本構文（`<?php ?>`）が書ける
# - [ ] `echo` で文字を表示できる
# - [ ] 変数を宣言して使える
# - [ ] 文字列、数値、真偽値の区別がつく
# - [ ] 配列の基本がわかる
# - [ ] コメントを書ける
# - [ ] `var_dump()` で変数の内容を確認できる
#
# ### 💡 次のステップ
#
# すべての課題が完了したら、次の章「PHPの基礎」に進みましょう！
