# %% [markdown]
# # 第4章: 配列 - 課題集
#
# ## 学習目標
# - 配列の基本操作ができる
# - 連想配列を使ってデータを管理できる
# - 多次元配列を扱える
# - 配列関数を使ってデータを加工できる
#
# ---
#
# ## 課題1: 基本的な配列操作
#
# ### 目標
# 配列の作成、要素の追加、削除、変更ができるようになりましょう。
#
# ### 問題
# 以下の操作を行ってください。
#
# **初期配列:**
# ```php
# $fruits = ["りんご", "ばなな", "みかん"];
# ```
#
# **実行する操作:**
# 1. 配列の要素数を表示する
# 2. 2番目の要素（"ばなな"）を表示する
# 3. 配列の末尾に"ぶどう"を追加する
# 4. 最初の要素を削除する
# 5. 1番目の要素を"メロン"に変更する
# 6. 最終的な配列の内容を表示する

# %%
<language>php</language><?php
$fruits = ["りんご", "ばなな", "みかん"];

// ここにコードを書いてください


?>

# %% [markdown]
# ### 確認ポイント
# - `count()` で要素数を取得できましたか？
# - インデックスは0から始まることを理解しましたか？
# - `array_push()` または `[]` で要素を追加できましたか？
# - `array_shift()` で最初の要素を削除できましたか？

# %% [markdown]
# ---
#
# ## 課題2: 連想配列で商品情報を管理
#
# ### 目標
# 連想配列を使って、意味のあるデータ構造を作れるようになりましょう。
#
# ### 問題
# 商品情報を連想配列で管理し、以下の操作を行ってください。
#
# **商品情報:**
# - 名前: "ノートPC"
# - 価格: 98000
# - 在庫数: 15
# - カテゴリ: "電化製品"
# - 評価: 4.5
#
# **操作:**
# 1. 商品情報を連想配列で作成
# 2. 在庫数を10減らす
# 3. カタログ番号（"ITEM-001"）を追加
# 4. 価格を10%値上げする
# 5. 最終的な商品情報を見やすく表示

# %%
<language>php</language><?php
// 商品情報を連想配列で作成
$product = [
    // ここにキーと値を追加してください
    
];

// 在庫数を10減らす


// カタログ番号を追加


// 価格を10%値上げする


// 商品情報を表示
echo "=== 商品情報 ===\n";
// ここに表示コードを追加してください


?>

# %% [markdown]
# ### 確認ポイント
# - 連想配列のキーと値のペアを理解しましたか？
# - 値の変更と追加が正しくできましたか？
# - foreachを使って見やすく表示できましたか？

# %% [markdown]
# ---
#
# ## 課題3: 多次元配列 - 成績表
#
# ### 目標
# 多次元配列を使って、複雑なデータ構造を扱いましょう。
#
# ### 問題
# 生徒の成績表を多次元配列で管理し、統計情報を計算してください。
#
# **成績データ:**
# - 田中: 国語85, 数学92, 英語78
# - 佐藤: 国語90, 数学88, 英語95
# - 鈴木: 国語78, 数学85, 英語82
#
# **計算する項目:**
# 1. 各生徒の平均点
# 2. 各教科の平均点
# 3. 全体の平均点
# 4. 最高点の生徒と教科

# %%
<language>php</language><?php
// 成績データを多次元配列で作成
$scores = [
    // ここにデータを追加してください
    
];

// 各生徒の平均点を計算


// 各教科の平均点を計算


// 全体の平均点を計算


// 最高点を見つける


// 結果を表示
echo "=== 成績統計 ===\n";
// ここに表示コードを追加してください


?>

# %% [markdown]
# ### 確認ポイント
# - 多次元配列のアクセス方法を理解しましたか？
# - ネストしたforeachを使えましたか？
# - 統計計算のロジックは正しいですか？

# %% [markdown]
# ---
#
# ## 課題4: 配列のソートと検索
#
# ### 目標
# 配列関数を使って、データの並べ替えと検索ができるようになりましょう。
#
# ### 問題
# 学生のリストから条件に合う学生を検索し、ソートしてください。
#
# **学生データ:**
# ```php
# $students = [
#     ["name" => "田中", "age" => 20, "score" => 85],
#     ["name" => "佐藤", "age" => 22, "score" => 92],
#     ["name" => "鈴木", "age" => 19, "score" => 78],
#     ["name" => "山田", "age" => 21, "score" => 88],
#     ["name" => "伊藤", "age" => 20, "score" => 95]
# ];
# ```
#
# **操作:**
# 1. 点数の昇順でソート
# 2. 点数が85点以上の学生を検索
# 3. 年齢が20歳の学生を検索
# 4. 名前が"鈴"で始まる学生を検索

# %%
<language>php</language><?php
$students = [
    ["name" => "田中", "age" => 20, "score" => 85],
    ["name" => "佐藤", "age" => 22, "score" => 92],
    ["name" => "鈴木", "age" => 19, "score" => 78],
    ["name" => "山田", "age" => 21, "score" => 88],
    ["name" => "伊藤", "age" => 20, "score" => 95]
];

// 1. 点数の昇順でソート


// 2. 点数が85点以上の学生を検索


// 3. 年齢が20歳の学生を検索


// 4. 名前が"鈴"で始まる学生を検索


// 結果を表示
?>

# %% [markdown]
# ### 確認ポイント
# - `usort()` で連想配列をソートできましたか？
# - `array_filter()` で条件に合う要素を抽出できましたか？
# - 検索ロジックは正しく動作していますか？

# %% [markdown]
# ---
#
# ## 課題5: 配列の結合と分割
#
# ### 目標
# 複数の配列を結合したり、配列を分割したりできるようになりましょう。
#
# ### 問題
# 以下の操作を行ってください。
#
# **1. 配列の結合**
# ```php
# $fruits1 = ["りんご", "ばなな"];
# $fruits2 = ["みかん", "ぶどう"];
# $fruits3 = ["メロン", "いちご"];
# ```
# これらを1つの配列に結合してください。
#
# **2. 配列のチャンク（分割）**
# 結合した配列を2つずつの要素に分割してください。
#
# **3. 配列の差分**
# ```php
# $all_users = ["田中", "佐藤", "鈴木", "山田", "伊藤"];
# $active_users = ["佐藤", "山田"];
# ```
# アクティブでないユーザー（inactive_users）を見つけてください。

# %%
<language>php</language><?php
// 1. 配列の結合
$fruits1 = ["りんご", "ばなな"];
$fruits2 = ["みかん", "ぶどう"];
$fruits3 = ["メロン", "いちご"];

// ここに結合コードを書いてください


// 2. 配列のチャンク（分割）


// 3. 配列の差分
$all_users = ["田中", "佐藤", "鈴木", "山田", "伊藤"];
$active_users = ["佐藤", "山田"];

// ここに差分コードを書いてください


// 結果を表示
?>

# %% [markdown]
# ### 確認ポイント
# - `array_merge()` で配列を結合できましたか？
# - `array_chunk()` で配列を分割できましたか？
# - `array_diff()` で差分を見つけられましたか？

# %% [markdown]
# ---
#
# ## 課題6: 総合演習 - ショッピングカート
#
# ### 目標
# 配列を使って、実用的なショッピングカートシステムを作りましょう。
#
# ### 問題
# ショッピングカートの管理システムを作成してください。
#
# **機能:**
# 1. 商品をカートに追加
# 2. カートの中身を表示
# 3. 合計金額を計算
# 4. 在庫チェック（在庫数より多く注文できない）
# 5. 会員割引の適用
#
# **商品マスタ:**
# ```php
# $products = [
#     "P001" => ["name" => "ノートPC", "price" => 98000, "stock" => 5],
#     "P002" => ["name" => "マウス", "price" => 2500, "stock" => 20],
#     "P003" => ["name" => "キーボード", "price" => 8500, "stock" => 15],
#     "P004" => ["name" => "モニター", "price" => 35000, "stock" => 8]
# ];
# ```
#
# **カートの内容:**
# - P001を2台注文
# - P002を3個注文
# - P004を1台注文

# %%
<language>php</language><?php
// 商品マスタ
$products = [
    "P001" => ["name" => "ノートPC", "price" => 98000, "stock" => 5],
    "P002" => ["name" => "マウス", "price" => 2500, "stock" => 20],
    "P003" => ["name" => "キーボード", "price" => 8500, "stock" => 15],
    "P004" => ["name" => "モニター", "price" => 35000, "stock" => 8]
];

// カートの内容
$cart = [
    "P001" => 2,
    "P002" => 3,
    "P004" => 1
];

// 会員情報
$is_member = true;
$member_discount_rate = 0.1;  // 10%引き

// 1. 在庫チェック


// 2. 合計金額を計算


// 3. 会員割引を適用


// 4. カートの中身を表示
echo "=== ショッピングカート ===\n";
// ここに表示コードを追加してください


?>

# %% [markdown]
# ### 確認ポイント
# - 在庫チェックのロジックは正しいですか？
# - 合計金額の計算は正しいですか？
# - 会員割引は正しく適用されていますか？
# - カートの表示は見やすいですか？

# %% [markdown]
# ---
#
# ## 📊 学習チェックリスト
#
# この章の課題を終えたら、以下のチェックリストで理解度を確認しましょう。
#
# - [ ] 基本的な配列操作（追加、削除、変更）ができる
# - [ ] 連想配列を作成して操作できる
# - [ ] 多次元配列を扱える
# - [ ] 配列をソートできる
# - [ ] 配列から要素を検索できる
# - [ ] 配列を結合・分割できる
# - [ ] 実用的なアプリケーションで配列を使える
#
# ### 💡 次のステップ
#
# すべての課題が完了したら、次の章「繰り返し処理」に進みましょう！
